# %%
import pandas as pd
starttime=pd.date_range('20190129', '20190130',freq='10Min') #生成一个时间段
starttime=pd.Series(starttime)

# %%
endtime=pd.date_range('201901290010', '20190130',freq='10Min') #生成一个时间段

# %%
endtime=pd.Series(endtime)

# %%
pd.DataFrame({'starttime':starttime,'endtime':endtime})
# Out:
#               starttime             endtime
# 0   2019-01-29 00:00:00 2019-01-29 00:10:00
# 1   2019-01-29 00:10:00 2019-01-29 00:20:00
# 2   2019-01-29 00:20:00 2019-01-29 00:30:00
# 3   2019-01-29 00:30:00 2019-01-29 00:40:00
# 4   2019-01-29 00:40:00 2019-01-29 00:50:00
# 5   2019-01-29 00:50:00 2019-01-29 01:00:00
# 6   2019-01-29 01:00:00 2019-01-29 01:10:00
# 7   2019-01-29 01:10:00 2019-01-29 01:20:00
# 8   2019-01-29 01:20:00 2019-01-29 01:30:00
# 9   2019-01-29 01:30:00 2019-01-29 01:40:00
# 10  2019-01-29 01:40:00 2019-01-29 01:50:00
# 11  2019-01-29 01:50:00 2019-01-29 02:00:00
# 12  2019-01-29 02:00:00 2019-01-29 02:10:00
# 13  2019-01-29 02:10:00 2019-01-29 02:20:00
# 14  2019-01-29 02:20:00 2019-01-29 02:30:00
# 15  2019-01-29 02:30:00 2019-01-29 02:40:00
# 16  2019-01-29 02:40:00 2019-01-29 02:50:00
# 17  2019-01-29 02:50:00 2019-01-29 03:00:00
# 18  2019-01-29 03:00:00 2019-01-29 03:10:00
# 19  2019-01-29 03:10:00 2019-01-29 03:20:00
# ...

# %%
one=pd.read_csv(r'D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\record_2019-01-01.csv')

# %%
one.head()
# Out:
#             time lineID  stationID  deviceID  status  \
# 0  2019/1/1 2:00      B         27      1354       0
# 1  2019/1/1 2:01      B          5       200       1
# 2  2019/1/1 2:01      B          5       247       0
# 3  2019/1/1 2:02      B          5       235       0
# 4  2019/1/1 2:03      B         23      1198       0
#
#                               userID  payType
# 0  D13f76f42c9a677c4add94d9e480fb5c5        3
# 1  D9a337d37d9512184b8e3fd477934b293        3
# 2  Dc9e179298617f40b782490c1f3e2346c        3
# 3  D9a337d37d9512184b8e3fd477934b293        3
# 4  Dd1cde61886c23fdb7ef1fdb76c9b1234        3

# %%
one['time']=pd.to_datetime(one['time'])

#by_seconds = one.resample('time')

one['flag'] = one['time'].dt.minute%10==0


#one['time'].dt.floor('10T').diff()

# %%
one
# Out:
#                        time lineID  stationID  deviceID  status  \
# 0       2019-01-01 02:00:00      B         27      1354       0
# 1       2019-01-01 02:01:00      B          5       200       1
# 2       2019-01-01 02:01:00      B          5       247       0
# 3       2019-01-01 02:02:00      B          5       235       0
# 4       2019-01-01 02:03:00      B         23      1198       0
# 5       2019-01-01 02:04:00      B          3       109       0
# 6       2019-01-01 02:04:00      B         27      1354       1
# 7       2019-01-01 02:05:00      B          4       141       0
# 8       2019-01-01 02:05:00      B         23      1198       0
# 9       2019-01-01 02:05:00      B         20      1036       1
# 10      2019-01-01 02:05:00      B          5       234       1
# 11      2019-01-01 02:05:00      B         20      1037       1
# 12      2019-01-01 02:06:00      C         55      2631       1
# 13      2019-01-01 02:06:00      B          5       194       0
# ...
