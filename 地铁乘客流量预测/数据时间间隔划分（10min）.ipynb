# %% [markdown]
# ### 1.2 数据预处理

# %% [markdown]
# #### 1.2.1 以10min时间段统计

# %% [markdown]
# #### 数据说明：
#
# 1、除第一行外，每行包含一条用户的刷卡记录
#
# 2、用户身份id，在用户刷卡类型为3时无法唯一标识用户身份。即此userid可能为多人使用，但在一次进出站期间可以视为同一用户。对于
# 其他取值的用户刷卡类型，对应的用户身份id可以唯一标识一个用户。
#
# 3、进出站状态：0为出站，1为进站

# %% [markdown]
# #### 1-4天

# %%
import pandas as pd
import numpy as np
ONE=pd.read_csv(r'D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\data1_4.csv')
#one.columns=['刷卡发生时间','地铁线路id','地铁站id','刷卡设备编号id','进出站状态','用户身份id','用户刷卡类型']

# %%
# 拆分时间
ONE['time']=pd.to_datetime(ONE['time'])
ONE['year']=ONE['time'].dt.year
ONE['month']=ONE['time'].dt.month
ONE['day']=ONE['time'].dt.day
ONE['hour']=ONE['time'].dt.hour
ONE['minute']=ONE['time'].dt.minute
bins=[-1,0,10,20,30,40,50,60]
ONE['did']=pd.cut(ONE['minute'].values,bins,right=False)

# %%
first=ONE
first=first.sort_values(by='time')
# 进站人数
FIRST=first.loc[first['status']==1]
IN=FIRST.groupby(['year','month','day','hour','did','stationID'])['userID'].count().reset_index()
# 出站人数
SECOND=first.loc[first['status']==0]
OUT=SECOND.groupby(['year','month','day','hour','did','stationID'])['userID'].count().reset_index()
IN_OUT=pd.merge(IN,OUT,on=['year','month','day','hour','did','stationID'])
IN_OUT.rename(columns={'userID_x':"IN",'userID_y':'OUT'},inplace=True)
IN_OUT.to_csv(r"D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\IN_OUT1_4.csv")
IN_OUT.head()
# Out:
#    year  month  day  hour       did  stationID  IN  OUT
# 0  2019      1    1     2   [0, 10)          5   2    3
# 1  2019      1    1     2   [0, 10)         27   1    1
# 2  2019      1    1     2   [0, 10)         41   1    1
# 3  2019      1    1     2   [0, 10)         77   1    1
# 4  2019      1    1     2  [10, 20)         31   4    1

# %% [markdown]
# #### 5-8天

# %%
ONE=pd.read_csv(r'D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\data5_8.csv')
ONE['time']=pd.to_datetime(ONE['time'])
ONE['year']=ONE['time'].dt.year
ONE['month']=ONE['time'].dt.month
ONE['day']=ONE['time'].dt.day
ONE['hour']=ONE['time'].dt.hour
ONE['minute']=ONE['time'].dt.minute
bins=[-1,0,10,20,30,40,50,60]
ONE['did']=pd.cut(ONE['minute'].values,bins,right=False)
first=ONE
first=first.sort_values(by='time')
# 进站人数
FIRST=first.loc[first['status']==1]
IN=FIRST.groupby(['year','month','day','hour','did','stationID'])['userID'].count().reset_index()
# 出站人数
SECOND=first.loc[first['status']==0]
OUT=SECOND.groupby(['year','month','day','hour','did','stationID'])['userID'].count().reset_index()
IN_OUT=pd.merge(IN,OUT,on=['year','month','day','hour','did','stationID'])
IN_OUT.rename(columns={'userID_x':"IN",'userID_y':'OUT'},inplace=True)
IN_OUT.to_csv(r"D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\IN_OUT5_8.csv")
# Out:
#    year  month  day  hour      did  stationID  IN  OUT
# 0  2019      1    5     0  [0, 10)          5  12    2
# 1  2019      1    5     0  [0, 10)         16   2    3
# 2  2019      1    5     0  [0, 10)         27   1    1
# 3  2019      1    5     0  [0, 10)         31   1    1
# 4  2019      1    5     0  [0, 10)         32   1    1

# %%
ONE=pd.read_csv(r'D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\data9_12.csv')
ONE['time']=pd.to_datetime(ONE['time'])
ONE['year']=ONE['time'].dt.year
ONE['month']=ONE['time'].dt.month
ONE['day']=ONE['time'].dt.day
ONE['hour']=ONE['time'].dt.hour
ONE['minute']=ONE['time'].dt.minute
bins=[-1,0,10,20,30,40,50,60]
ONE['did']=pd.cut(ONE['minute'].values,bins,right=False)
first=ONE
first=first.sort_values(by='time')
# 进站人数
FIRST=first.loc[first['status']==1]
IN=FIRST.groupby(['year','month','day','hour','did','stationID'])['userID'].count().reset_index()
# 出站人数
SECOND=first.loc[first['status']==0]
OUT=SECOND.groupby(['year','month','day','hour','did','stationID'])['userID'].count().reset_index()
IN_OUT=pd.merge(IN,OUT,on=['year','month','day','hour','did','stationID'])
IN_OUT.rename(columns={'userID_x':"IN",'userID_y':'OUT'},inplace=True)
IN_OUT.to_csv(r"D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\IN_OUT9_12.csv")

# %%
ONE=pd.read_csv(r'D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\data13_16.csv')
ONE['time']=pd.to_datetime(ONE['time'])
ONE['year']=ONE['time'].dt.year
ONE['month']=ONE['time'].dt.month
ONE['day']=ONE['time'].dt.day
ONE['hour']=ONE['time'].dt.hour
ONE['minute']=ONE['time'].dt.minute
bins=[-1,0,10,20,30,40,50,60]
ONE['did']=pd.cut(ONE['minute'].values,bins,right=False)
first=ONE
first=first.sort_values(by='time')
# 进站人数
FIRST=first.loc[first['status']==1]
IN=FIRST.groupby(['year','month','day','hour','did','stationID'])['userID'].count().reset_index()
# 出站人数
SECOND=first.loc[first['status']==0]
OUT=SECOND.groupby(['year','month','day','hour','did','stationID'])['userID'].count().reset_index()
IN_OUT=pd.merge(IN,OUT,on=['year','month','day','hour','did','stationID'])
IN_OUT.rename(columns={'userID_x':"IN",'userID_y':'OUT'},inplace=True)
IN_OUT.to_csv(r"D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\IN_OUT13_16.csv")

# %%
ONE=pd.read_csv(r'D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\data17_20.csv')
ONE['time']=pd.to_datetime(ONE['time'])
ONE['year']=ONE['time'].dt.year
ONE['month']=ONE['time'].dt.month
ONE['day']=ONE['time'].dt.day
ONE['hour']=ONE['time'].dt.hour
ONE['minute']=ONE['time'].dt.minute
bins=[-1,0,10,20,30,40,50,60]
ONE['did']=pd.cut(ONE['minute'].values,bins,right=False)
first=ONE
first=first.sort_values(by='time')
# 进站人数
FIRST=first.loc[first['status']==1]
IN=FIRST.groupby(['year','month','day','hour','did','stationID'])['userID'].count().reset_index()
# 出站人数
SECOND=first.loc[first['status']==0]
OUT=SECOND.groupby(['year','month','day','hour','did','stationID'])['userID'].count().reset_index()
IN_OUT=pd.merge(IN,OUT,on=['year','month','day','hour','did','stationID'])
IN_OUT.rename(columns={'userID_x':"IN",'userID_y':'OUT'},inplace=True)
IN_OUT.to_csv(r"D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\IN_OUT17_20.csv")

# %%
ONE=pd.read_csv(r'D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\data21_25.csv')
ONE['time']=pd.to_datetime(ONE['time'])
ONE['year']=ONE['time'].dt.year
ONE['month']=ONE['time'].dt.month
ONE['day']=ONE['time'].dt.day
ONE['hour']=ONE['time'].dt.hour
ONE['minute']=ONE['time'].dt.minute
bins=[-1,0,10,20,30,40,50,60]
ONE['did']=pd.cut(ONE['minute'].values,bins,right=False)
first=ONE
first=first.sort_values(by='time')
# 进站人数
FIRST=first.loc[first['status']==1]
IN=FIRST.groupby(['year','month','day','hour','did','stationID'])['userID'].count().reset_index()
# 出站人数
SECOND=first.loc[first['status']==0]
OUT=SECOND.groupby(['year','month','day','hour','did','stationID'])['userID'].count().reset_index()
IN_OUT=pd.merge(IN,OUT,on=['year','month','day','hour','did','stationID'])
IN_OUT.rename(columns={'userID_x':"IN",'userID_y':'OUT'},inplace=True)
IN_OUT.to_csv(r"D:\Entertainment\Prediction of Metro Passenger Flow\Metro_train\IN_OUT21_25.csv")
